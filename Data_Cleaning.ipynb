# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("melb_data.csv")
print(data.shape)
data.head()
# Out:
# (13580, 22)
#   Unique ID      Suburb           Address  Rooms Type    Price Method SellerG  \
# 0      ID_1  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1      ID_2  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2      ID_3  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3      ID_4  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4      ID_5  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5  ...         1  1.0       202           NaN
# 1  04-02-2016       2.5  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5  ...         2  1.0        94           NaN
# 4  04-06-2016       2.5  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# ...

# %%
data['Unique ID'] = data['Unique ID'].apply(lambda x:int(x[3:]))
data.set_index("Unique ID", inplace=True)
data.tail()
# Out:
#                   Suburb        Address  Rooms Type    Price Method   SellerG  \
# Unique ID
# 13576      Wheelers Hill   12 Strada Cr      4    h  1245000      S     Barry
# 13577       Williamstown  77 Merrett Dr      3    h  1031000     SP  Williams
# 13578       Williamstown    83 Power St      3    h  1170000      S     Raine
# 13579       Williamstown   96 Verdon St      4    h  2500000     PI   Sweeney
# 13580         Yarraville     6 Agnes St      4    h  1285000     SP   Village
#
#                  Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# Unique ID                                  ...
# 13576      26-08-2017      16.7      3150  ...         2  2.0       652
# 13577      26-08-2017       6.8      3016  ...         2  2.0       333
# 13578      26-08-2017       6.8      3016  ...         2  4.0       436
# 13579      26-08-2017       6.8      3016  ...         1  5.0       866
# 13580      26-08-2017       6.3      3013  ...         1  1.0       362
#
# ...

# %%
cat_features = [feature for feature in data.columns if data[feature].dtypes == 'O']
cat_features
# Out:
# ['Suburb',
#  'Address',
#  'Type',
#  'Method',
#  'SellerG',
#  'Date',
#  'CouncilArea',
#  'Regionname']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data[cat_features] = data[cat_features].apply(lambda x:le.fit_transform(x))
print(data.dtypes)
# Out:
# Suburb             int32
# Address            int32
# Rooms              int64
# Type               int32
# Price              int64
# Method             int32
# SellerG            int32
# Date               int32
# Distance         float64
# Postcode           int64
# Bedroom2           int64
# Bathroom           int64
# Car              float64
# Landsize           int64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea        int32
# Lattitude        float64
# Longtitude       float64
# Regionname         int32
# Propertycount      int64
# dtype: object

# %%
features_with_na=[features for features in data.columns if data[features].isnull().sum()>1]
data[features_with_na] = data[features_with_na].apply(lambda x:x.fillna(x.median()))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13580 entries, 1 to 13580
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  int32
#  1   Address        13580 non-null  int32
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  int32
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  int32
#  6   SellerG        13580 non-null  int32
#  7   Date           13580 non-null  int32
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  float64
#  16  CouncilArea    13580 non-null  int32
# ...

# %%
data['Car'] = data['Car'].astype(int)
data['YearBuilt'] = data['YearBuilt'].astype(int)

# %%
data.describe()
# Out:
#              Suburb       Address         Rooms          Type         Price  \
# count  13580.000000  13580.000000  13580.000000  13580.000000  1.358000e+04
# mean     155.307953   6687.248012      2.937997      0.526362  1.075684e+06
# std       90.307844   3859.711645      0.955748      0.832878  6.393107e+05
# min        0.000000      0.000000      1.000000      0.000000  8.500000e+04
# 25%       70.000000   3345.750000      2.000000      0.000000  6.500000e+05
# 50%      154.000000   6684.500000      3.000000      0.000000  9.030000e+05
# 75%      234.000000  10028.250000      3.000000      1.000000  1.330000e+06
# max      313.000000  13377.000000     10.000000      2.000000  9.000000e+06
#
#              Method       SellerG          Date      Distance      Postcode  \
# count  13580.000000  13580.000000  13580.000000  13580.000000  13580.000000
# mean       1.407290    130.810972     28.924448     10.137776   3105.301915
# ...

# %%
print("Mean value of Rooms feature :", data["Rooms"].mean())
print("Median value of Rooms feature :", data["Rooms"].median())
print("Mode of Rooms feature :", data["Rooms"].mode()[0])
print("Variance of Rooms feature :", data["Rooms"].var(),"\n")

print("Mean value of Price feature :", data["Price"].mean())
print("Median value of Price feature :", data["Price"].median())
print("Mode of Price feature :", data["Price"].mode()[0])
print("Variance of Price feature :", data["Price"].var())
# Out:
# Mean value of Rooms feature : 2.9379970544919
# Median value of Rooms feature : 3.0
# Mode of Rooms feature : 3
# Variance of Rooms feature : 0.9134541217971167
#
# Mean value of Price feature : 1075684.079455081
# Median value of Price feature : 903000.0
# Mode of Price feature : 1100000
# Variance of Price feature : 408718202199.9009
